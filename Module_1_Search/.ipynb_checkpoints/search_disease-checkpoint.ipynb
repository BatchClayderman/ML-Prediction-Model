# %%
import psycopg2
import pandas as pd
import numpy as np
import os
pd.set_option('display.max_columns', None) #show all columns
pd.set_option('max_colwidth',None)

# %%
def search_disease(name, download_as=''):
    temp = name.lower()
    for i in temp:
        if i > "z" or i < "a":
            assert "TypeError"
    del temp
    conn = psycopg2.connect(database="mimic", user="postgres",
                            password="pandora", host="127.0.0.1", port="5432")
    cursor = conn.cursor()
    cursor.execute("""select subject_id, hadm_id, icd9_code, seq_num, long_title 
    from (mimic.diagnoses_icd 
    left join mimic.d_icd_diagnoses using (icd9_code)) 
    where long_title like """ + "'%" + name + "%'")
    result = cursor.fetchall()
    if(len(result)!=0):
        colnames = [desc[0] for desc in cursor.description]
        columns = cursor.fetchall()
        cursor.close()
        conn.close()
        columns = pd.DataFrame(columns)
        result = pd.DataFrame(result)
        result.columns = colnames
    if(download_as!=''):
        result.to_csv(os.path.dirname(os.getcwd())+'/data/download data/' + download_as + '.csv', index=False)
    print('there are', len(result['long_title'].unique()), 'related diseases of', name, ':\n', 
          result['long_title'].unique())
    
    return result

# %%
search_disease(name = 'Gout', download_as='')
# Out:
# there are 4 related diseases of Gout :
#  ['Gouty arthropathy, unspecified' 'Gouty tophi of other sites, except ear'
#  'Gout with other specified manifestations' 'Gout, unspecified']
#       subject_id  hadm_id icd9_code  seq_num                      long_title
# 0          30754   129814     27400       14  Gouty arthropathy, unspecified
# 1          41606   134057     27400        6  Gouty arthropathy, unspecified
# 2          47194   149348     27400        7  Gouty arthropathy, unspecified
# 3          48826   175744     27400       21  Gouty arthropathy, unspecified
# 4          54777   127689     27400        9  Gouty arthropathy, unspecified
# ...          ...      ...       ...      ...                             ...
# 2109       97330   197571      2749       17               Gout, unspecified
# 2110       97023   148411      2749       15               Gout, unspecified
# 2111       95561   121289      2749       24               Gout, unspecified
# 2112       95561   152354      2749       17               Gout, unspecified
# 2113       96008   186366      2749       28               Gout, unspecified
#
# [2114 rows x 5 columns]
