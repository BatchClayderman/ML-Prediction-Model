# %%
import psycopg2
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None) #show all columns
pd.set_option('max_colwidth',None)

# %%
surgery=pd.read_csv('original data/surgery.csv')

# %%
def search_table(s='*', f='admissions', w='', like='', download_as=''):
    temp=s.lower()
    for i in temp:
        if i>"z" or i<"a":
            assert "TypeError"
    del temp
    conn = psycopg2.connect(database="mimic", user="postgres",
                            password="pandora", host="127.0.0.1", port="5432")
    cursor = conn.cursor()
    if (w!='')&(like!=''):
        cursor.execute("select " + s + " from mimiciii." + f +' where '+ w +
                       ' like ' + "'%"+ like +"%'")
    elif (w!='')&(like=='') :
        cursor.execute("select " + s + " from mimiciii." + f +' where '+ w)
    else:
        cursor.execute("select " + s + " from mimiciii." + f)
    table = cursor.fetchall()
    if(len(table)!=0):
        colnames = [desc[0] for desc in cursor.description]
        columns = cursor.fetchall()
        cursor.close()
        conn.close()
        columns=pd.DataFrame(columns)
        table=pd.DataFrame(table)
        table.columns=colnames
    if(download_as!=''):
        table.to_csv('download data/'+download_as+'.csv', index=False)
    return table

# %%
def searchSurgery(surgery_name, download_as=''):
    result=surgery
    index=result['long_title'].str.contains(surgery_name)
    result=surgery.loc[index[index.values==True].index,:]
    if download_as!='':
        res.to_csv('download data/'+download_as+'.csv', index=False)
    print('there are', len(result['long_title'].unique()), 'related surgery of', surgery_name, ':\n', 
          result['long_title'].unique())
    return result

# %%
res=searchSurgery(surgery_name='', download_as='')
res
# Out:
# there are 2056 related surgery of  :
#  ['Prophylactic administration of vaccine against other diseases'
#  'Enteral infusion of concentrated nutritional substances'
#  'Continuous invasive mechanical ventilation for 96 consecutive hours or more'
#  ... 'Temporary (partial) therapeutic endovascular occlusion of vessel'
#  'Revision of ureterointestinal anastomosis'
#  'Non-coronary intra-operative fluorescence vascular angiography [IFVA]']
#         row_id  subject_id  hadm_id  seq_num  icd9_code  \
# 0       109376           2   163353        1     9955.0
# 1        44189           3   145834        6      966.0
# 2        44187           3   145834        4     9672.0
# 3        44186           3   145834        3     8964.0
# 4        44185           3   145834        2     9962.0
# ...        ...         ...      ...      ...        ...
# 247841  174287       99999   113369        3     8162.0
# 247842  174289       99999   113369        5     8451.0
# 247843  174288       99999   113369        4     9979.0
# 247844  174285       99999   113369        1     8108.0
# 247845  174286       99999   113369        2     8051.0
#
#                      short_title  \
# 0                Vaccination NEC
# 1        Entral infus nutrit sub
# 2       Cont inv mec ven 96+ hrs
# 3       Pulmon art wedge monitor
# 4         Heart countershock NEC
# ...                          ...
# 247841   Fus/refus 2-3 vertebrae
# 247842  Ins spinal fusion device
# 247843  Other therapeu apheresis
# 247844  Lumb/lmbsac fus ant/post
# 247845   Excision intervert disc
#
#                                                                          long_title
# 0                     Prophylactic administration of vaccine against other diseases
# 1                           Enteral infusion of concentrated nutritional substances
# 2       Continuous invasive mechanical ventilation for 96 consecutive hours or more
# 3                                                 Pulmonary artery wedge monitoring
# 4                                              Other electric countershock of heart
# ...                                                                             ...
# 247841                                          Fusion or refusion of 2-3 vertebrae
# 247842                                  Insertion of interbody spinal fusion device
# 247843                                                  Other therapeutic apheresis
# 247844    Lumbar and lumbosacral fusion of the anterior column, posterior technique
# 247845                                              Excision of intervertebral disc
#
# [246178 rows x 7 columns]
