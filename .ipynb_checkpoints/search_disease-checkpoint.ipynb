# %%
import psycopg2
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None) #show all columns
pd.set_option('max_colwidth',None)

# %%
disease=pd.read_csv('original data/disease.csv')

# %%
def search_table(s='*', f='admissions', w='', like='', download_as=''):
    temp=s.lower()
    for i in temp:
        if i>"z" or i<"a":
            assert "TypeError"
    del temp
    conn = psycopg2.connect(database="mimic", user="postgres",
                            password="pandora", host="127.0.0.1", port="5432")
    cursor = conn.cursor()
    if (w!='')&(like!=''):
        cursor.execute("select " + s + " from mimiciii." + f +' where '+ w +
                       ' like ' + "'%"+ like +"%'")
    elif (w!='')&(like=='') :
        cursor.execute("select " + s + " from mimiciii." + f +' where '+ w)
    else:
        cursor.execute("select " + s + " from mimiciii." + f)
    table = cursor.fetchall()
    if(len(table)!=0):
        colnames = [desc[0] for desc in cursor.description]
        columns = cursor.fetchall()
        cursor.close()
        conn.close()
        columns=pd.DataFrame(columns)
        table=pd.DataFrame(table)
        table.columns=colnames
    if(download_as!=''):
        table.to_csv('download data/'+download_as+'.csv', index=False)
    return table

# %%
def searchDisease(disease_name, download_as=''):
    result=disease
    index=result['long_title'].str.contains(disease_name)
    result=disease.loc[index[index.values==True].index,:]
    if download_as!='':
        result.to_csv('download data/'+download_as+'.csv', index=False)
    print('there are', len(result['long_title'].unique()), 'related diseases of', disease_name, ':\n', 
          result['long_title'].unique())
    return result

# %%
# please input the name of a certain disease to search the patients
res=searchDisease(disease_name='', download_as='')
res
# Out:
# there are 2 related diseases of troke :
#  ['Family history of stroke (cerebrovascular)' 'Heat stroke and sunstroke']
#         subject_id  hadm_id  seq_num icd9_code              short_title  \
# 21809         3127   157135     29.0      V171         Family hx-stroke
# 27081         3509   160447      2.0      V171         Family hx-stroke
# 28577         2719   173993     16.0      V171         Family hx-stroke
# 71336         5506   152512      1.0      9920  Heat stroke & sunstroke
# 217701       21097   128446      7.0      V171         Family hx-stroke
# 236160       20336   134036      8.0      9920  Heat stroke & sunstroke
# 252959       21570   113978      8.0      V171         Family hx-stroke
# 288840       25888   198508      1.0      9920  Heat stroke & sunstroke
# 300953       27409   196645     12.0      V171         Family hx-stroke
# 337407       28210   111757      6.0      V171         Family hx-stroke
# ...
